# %% [raw]
#  0   rev_Mean          Doanh thu trung bình hàng tháng (số tiền phí)
#  1   mou_Mean          Số phút sử dụng trung bình hàng tháng
#  2   totmrc_Mean       Tổng phí định kỳ hàng tháng trung bình
#  3   da_Mean           Số lượng trung bình các cuộc gọi hỗ trợ danh bạ
#  4   ovrmou_Mean       Số phút sử dụng vượt mức trung bình
#  5   ovrrev_Mean       Doanh thu vượt mức trung bình
#  6   vceovr_Mean       Doanh thu trung bình của dịch vụ thoại vượt chuẩn
#  7   datovr_Mean       Doanh thu trung bình của dữ liệu vượt mức
#  8   roam_Mean         Số lượng cuộc gọi chuyển vùng trung bình
#  9   change_mou        Tỷ lệ phần trăm thay đổi trong số phút sử dụng hàng tháng so với mức trung bình ba tháng trước
#  10  change_rev        Tỷ lệ phần trăm thay đổi trong doanh thu hàng tháng so với mức trung bình ba tháng trước
#  11  drop_vce_Mean     Số lượng trung bình các cuộc gọi thoại bị rớt (không thành công)
#  12  drop_dat_Mean     Số lượng trung bình các cuộc gọi dữ liệu bị hủy (thất bại)
#  13  blck_vce_Mean     Số lượng trung bình các cuộc gọi thoại bị chặn (không thành công)
#  14  blck_dat_Mean     Số lượng trung bình các cuộc gọi dữ liệu bị chặn (không thành công)
#  15  unan_vce_Mean     Số lượng trung bình các cuộc gọi thoại không được trả lời
#  16  unan_dat_Mean     Số lượng trung bình các cuộc gọi dữ liệu không được trả lời
#  17  plcd_vce_Mean     Số lượng trung bình các cuộc gọi thoại đã thực hiện
#  18  plcd_dat_Mean     Số lượng trung bình các cuộc gọi dữ liệu đã thử được thực hiện
#  19  recv_vce_Mean     Số lượng trung bình các cuộc gọi thoại nhận được
#  20  recv_sms_Mean     Số lượng trung bình tin nhắn SMS nhận được
#  21  comp_vce_Mean     Số lượng trung bình các cuộc gọi thoại đã hoàn thành
#  22  comp_dat_Mean     Số lượng trung bình các cuộc gọi dữ liệu đã hoàn thành
#  23  custcare_Mean     Số lượng trung bình các cuộc gọi chăm sóc khách hàng
#  24  ccrndmou_Mean     Số phút làm tròn trung bình sử dụng các cuộc gọi chăm sóc khách hàng
#  25  cc_mou_Mean       Số phút sử dụng trung bình không làm tròn của các cuộc gọi chăm sóc khách hàng (xem CUSTCARE_MEAN)
#  26  inonemin_Mean     Số lượng cuộc gọi đến trung bình dưới một phút
#  27  threeway_Mean     Số lượng trung bình của cuộc gọi ba chiều
#  28  mou_cvce_Mean     Số phút sử dụng trung bình không làm tròn của các cuộc gọi thoại đã hoàn thành
#  29  mou_cdat_Mean     Số phút sử dụng trung bình chưa làm tròn của các cuộc gọi dữ liệu đã hoàn thành
#  30  mou_rvce_Mean     Số phút sử dụng trung bình không làm tròn của các cuộc gọi thoại đã nhận
#  31  owylis_vce_Mean   Số lượng trung bình các cuộc gọi thoại không dây đi đến không dây
#  32  mouowylisv_Mean   Số phút sử dụng trung bình không làm tròn của các cuộc gọi thoại không dây đi đến không dây
#  33  iwylis_vce_Mean   Số lượng trung bình các cuộc gọi thoại không dây đến không dây
#  34  mouiwylisv_Mean   Số phút sử dụng trung bình không làm tròn của các cuộc gọi thoại không dây đến không dây
#  35  peak_vce_Mean     Số lượng trung bình các cuộc gọi thoại đến và đi cao điểm
#  36  peak_dat_Mean     Số lượng trung bình các cuộc gọi dữ liệu đỉnh
#  37  mou_peav_Mean     Số phút trung bình không làm tròn của các cuộc gọi thoại cao điểm
#  38  mou_pead_Mean     Số phút sử dụng trung bình không làm tròn của các cuộc gọi dữ liệu cao điểm
#  39  opk_vce_Mean      Số lượng trung bình các cuộc gọi thoại ngoài giờ cao điểm
#  40  opk_dat_Mean      Số lượng trung bình các cuộc gọi dữ liệu ngoài giờ cao điểm
#  41  mou_opkv_Mean     Số phút sử dụng trung bình không làm tròn của các cuộc gọi thoại ngoài giờ cao điểm
#  42  mou_opkd_Mean     Số phút sử dụng trung bình không làm tròn của các cuộc gọi dữ liệu ngoài giờ cao điểm
#  43  drop_blk_Mean     Số lượng trung bình các cuộc gọi bị rớt hoặc bị chặn
#  44  attempt_Mean      Số lượng cuộc gọi trung bình đã thử
#  45  complete_Mean     Số lượng cuộc gọi hoàn thành trung bình
#  46  callfwdv_Mean     Số lượng cuộc gọi chuyển tiếp trung bình
#  47  callwait_Mean     Số lượng cuộc gọi chờ trung bình
#  48  churn             Trường hợp churn trong khoảng 31-60 ngày sau ngày quan sát
#  49  months            Tổng số tháng phục vụ
#  50  uniqsubs          Số lượng người đăng ký duy nhất trong hộ gia đình
#  51  actvsubs          Số lượng thuê bao đang hoạt động trong hộ gia đình
#  52  new_cell          Người dùng điện thoại di động mới
#  53  crclscod          Mã lớp tín chỉ
#  54  asl_flag          Giới hạn chi tiêu tài khoản
#  55  totcalls          Tổng số cuộc gọi trong suốt vòng đời của khách hàng
#  56  totmou            Tổng số phút sử dụng trong suốt thời gian sử dụng của khách hàng
#  57  totrev            Tổng doanh thu
#  58  adjrev            Tổng doanh thu được điều chỉnh theo hóa đơn trong suốt thời gian sử dụng của khách hàng
#  59  adjmou            Tổng số phút sử dụng được điều chỉnh theo hóa đơn trong suốt thời gian sử dụng của khách hàng
#  60  adjqty            Tổng số cuộc gọi được điều chỉnh theo hóa đơn trong suốt vòng đời của khách hàng
#  61  avgrev            Doanh thu trung bình hàng tháng trong suốt vòng đời của khách hàng
#  62  avgmou            Số phút sử dụng trung bình hàng tháng trong suốt thời gian sử dụng của khách hàng
#  63  avgqty            Số cuộc gọi trung bình hàng tháng trong suốt vòng đời của khách hàng
#  64  avg3mou           Số phút sử dụng trung bình hàng tháng trong ba tháng trước
#  65  avg3qty           Số cuộc gọi trung bình hàng tháng trong ba tháng trước
#  66  avg3rev           Doanh thu trung bình hàng tháng trong ba tháng trước
#  67  avg6mou           Số phút sử dụng trung bình hàng tháng trong sáu tháng trước
#  68  avg6qty           Số cuộc gọi trung bình hàng tháng trong sáu tháng trước
#  69  avg6rev           Doanh thu trung bình hàng tháng trong sáu tháng trước
#  70  prizm_social_one  Chỉ thư nhóm xã hội
#  71  area              Khu vực địa lý
#  72  dualband          Băng tần kép
#  73  refurb_new        Điện thoại: tân trang hoặc mới
#  74  hnd_price         Giá điện thoại hiện tại
#  75  phones            Số lượng điện thoại đã phát hành
#  76  models            Số lượng mẫu đã phát hành
#  77  hnd_webcap        Khả năng web của điện thoại
#  78  truck             Chỉ báo xe tải
#  79  rv                Chỉ báo RV
#  80  ownrent           Tình trạng chủ nhà/người thuê nhà
#  81  lor               Thời gian cư trú
#  82  dwlltype          Loại đơn vị nhà ở
#  83  marital           Tình trạng hôn nhân
#  84  adults            Số người lớn trong hộ gia đình
#  85  infobase          InfoBase phù hợp
#  86  income            Thu nhập ước tính
#  87  numbcars          Số lượng xe đã biết
#  88  HHstatin          Chỉ số tình trạng hộ gia đình hàng đầu
#  89  dwllsize          Kích thước nhà ở
#  90  forgntvl          Biến giả du lịch nước ngoài
#  91  ethnic            Mã số tổng hợp dân tộc
#  92  kid0_2            Trẻ em từ 0 - 2 tuổi trong hộ gia đình
#  93  kid3_5            Trẻ em từ 3 - 5 tuổi trong hộ gia đình
#  94  kid6_10           Trẻ em từ 6 - 10 tuổi trong hộ gia đình
#  95  kid11_15          Trẻ em từ 11 - 15 tuổi trong hộ gia đình
#  96  kid16_17          Trẻ em 16 - 17 tuổi trong hộ gia đình
#  97  creditcd          Chỉ báo thẻ tín dụng
#  98  eqpdays           Số ngày (tuổi) của thiết bị hiện tại
#  99  Customer_ID       Mã định danh khách hàng duy nhất
